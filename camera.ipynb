# %%
from jetbot import Robot
import time

robot = Robot()

# %%
# Moving
robot.left_motor.value = 0.4
robot.right_motor.value = 0.4

# %%
robot.left_motor.value = 0
robot.right_motor.value = 0

# %%
# Vertical motors for camera

robot.up(1)
time.sleep(2.0)
robot.vertical_motors_stop()

# %%
from servoserial import ServoSerial
import time
servo_device = ServoSerial()
# Out:
# serial Open!
# WARNING: Carrier board is not from a Jetson Developer Kit.
# WARNNIG: Jetson.GPIO library has not been verified with this carrier board,
# WARNING: and in fact is unlikely to work correctly.

# %%
servo_device.Servo_serial_control(1, 1000) # 중앙값 1000, 범위 오른쪽 끝 0 ~ 2000 왼쪽끝
time.sleep(0.1)
servo_device.Servo_serial_control(2, 1200) # 900 ~ 3000

# %%
servo_device.Servo_serial_double_control(1, 1000, 2, 1200)  # default 각도

# %%
from jetbot import Camera
from jetbot import bgr8_to_jpeg

camera = Camera.instance(width=720, height=720)  # 720x720 픽셀 이미지 사용

# %%
from servoserial import ServoSerial
import time
servo_device = ServoSerial()
# Out:
# WARNING: Carrier board is not from a Jetson Developer Kit.
# WARNNIG: Jetson.GPIO library has not been verified with this carrier board,
# WARNING: and in fact is unlikely to work correctly.
# serial Open!

# %%
import traitlets
import ipywidgets.widgets as widgets
from IPython.display import display

detect_image = widgets.Image(format='jpeg', width=300, height=300)
display(detect_image)
# Out:
# Image(value=b'', format='jpeg', height='300', width='300')

# %%
import cv2

# %%
while 1:
    frame = camera.value
    frame = cv2.resize(frame, (300, 300))  # 이미지를 학습 데이터와 동일한 크기로 변환
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)  # 흑백 이미지로 변환하여 검출에 사용
    
    
    detect_image.value = bgr8_to_jpeg(frame)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-e0ee03f6e5d2>", line 3, in <module>
#     frame = cv2.resize(frame, (300, 300))  # 이미지를 학습 데이터와 동일한 크기로 변환
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...
